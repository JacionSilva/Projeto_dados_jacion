# %%
#bibliotestas importação
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

#data Frame
dataFrame = pd.read_csv('https://gist.githubusercontent.com/altinodantas/2d57753e48eeacd20a6c1ff6ebe94f6d/raw/e6868648a75a340a651b5494e0f210f1010810aa/dados-delivery.csv')
dataFrame

# Atribui a lista de avaliações à variável "avaliacao"
avaliacao = dataFrame["avaliacao"]
tempoentregareal = dataFrame["tempo-entrega-real"]

# Cria uma lista vazia para armazenar as avaliações maiores que 8
avaliacaomaiorque8 = []
tempoentregareal2 = []
dataFrame2=[]

# Itera sobre a lista de avaliações
for avaliacao in avaliacao:

    # Se a avaliação for maior que 8, adiciona-a à lista vazia
    if avaliacao > 8.0:
        avaliacaomaiorque8.append(avaliacao)

for tempoentregareal in tempoentregareal:
    if tempoentregareal != '':
        tempoentregareal2.append(tempoentregareal)

dataFrame2={'tempo_entrega':tempoentregareal2,'avaliacao':avaliacaomaiorque8}
# Imprime a lista de avaliações maiores que 8
#print(avaliacaomaiorque8)
#print(tempoentregareal2)
print(dataFrame2)

#exibindo o Gáfico
ax = sns.scatterplot(data = dataFrame2, x='tempo_entrega',y='avaliacao')
ax.set(xlabel='Avaliação (x)',
       ylabel = 'tempo_entrega_real');

#grafico 
plt.figure(figsize=(10,6))
plt.title("Modelo de Grafico Dispersão")
plt.scatter(x=avaliacaomaiorque8, y=tempoentregareal2, color='red', s=20)
plt.grid(True)#permite adicionar colunas e linhas ou gride
plt.show()
# Out:
# {'tempo_entrega': [15.0, 60.0, 30.0, 15.0, 75.0, 30.0, 15.0, 60.0, 15.0, 30.0, 15.0, 60.0, 75.0, 90.0, 60.0, 30.0, 60.0, 105.0, 15.0, 30.0, 90.0, 60.0, 75.0, 60.0, 15.0, 15.0, 30.0, 60.0, 75.0, 30.0, 95.0, 55.0, 15.0, 175.0, 25.0, 100.0, 5.0, 35.0, 60.0, 95.0, 90.0, 165.0, 150.0, 60.0, 40.0, 35.0, 15.0, 65.0, 35.0, 55.0, 30.0, 75.0, 15.0, 45.0, 45.0, 105.0, 110.0, 170.0, 180.0, 55.0, 155.0, 135.0, 125.0, 85.0, 125.0, 55.0, 95.0, 55.0, 145.0, 175.0, 30.0, 20.0, 20.0, 45.0, 130.0, 145.0, 15.0, 160.0, 30.0, 150.0, 60.0, 30.0, 40.0, 40.0, 65.0, 40.0, 165.0, 145.0, 100.0, 35.0, 45.0, 130.0, 75.0, 110.0, 50.0, 10.0, 15.0, 80.0, 50.0, 90.0, 135.0, 135.0, 25.0, 75.0, 25.0, 45.0, 30.0, 135.0, 80.0, 165.0, 55.0, 110.0, 10.0, 15.0, 20.0, 160.0, 80.0, 120.0, 120.0, 145.0, 25.0, 180.0, 60.0, 145.0, 160.0, 175.0, 20.0, 90.0, 15.0, 20.0, 60.0, 50.0, 140.0, 130.0, 55.0, 35.0, 45.0, 85.0, 70.0, 40.0, 80.0, 175.0, 145.0, 65.0, 85.0, 50.0, 120.0, 110.0, 90.0, 55.0, 150.0, 70.0, 60.0, 25.0, 75.0, 145.0,
# ...
